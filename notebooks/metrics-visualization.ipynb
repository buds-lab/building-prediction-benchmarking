# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize

# list of models
# Commented few models because they produced very big results which interfere visualization
models = [#'RandomForestRegressor',
          #'AdaBoostRegressor',
          #'BaggingRegressor',
          #'DecisionTreeRegressor',
          'DummyRegressor',
          #'ExtraTreeRegressor',
          #'ExtraTreesRegressor',
          #'GaussianProcessRegressor',
          #'GradientBoostingRegressor',
          #'HuberRegressor',
          #'KNeighborsRegressor',
          #'MLPRegressor',
          #'PassiveAggressiveRegressor',
          #'RANSACRegressor',
          #'SGDRegressor',
          #'TheilSenRegressor'
         ]

dataFrames = []
#buildingtypes = ['Office', 'PrimClass', 'UnivClass', 'UnivDorm', 'UnivLab']
for model in models:
    data = pd.read_csv('../results/' + model + '_metrics_PrimClass.csv', index_col='Unnamed: 0')
    dataFrames.append(data)

# %%
# Generate different line styles
# 24 different different lines will be generated
lineStyles = ['-', '--', '-.', ':']
lineColors = ['b', 'g', 'r', 'c', 'm', 'y']
styles = []

for j in range(3):
    for i in range(5):
        styles.append(lineColors[i] + lineStyles[(i + j) % 4])

# %%
# MAPE,NMBE,CVRSME,RSQUARED possible arguments
# Creates visualization based on argument
def visualize(arg):
    dataList = []
    values = []
    for elem in dataFrames:
        dataList.append(elem[arg].values)
    
    for i in range(len(dataList)):
        values.append(dataList[i])
    lines = []
    plt.style.use('seaborn-whitegrid')
    plt.figure(figsize=(15,10))
    
    for i in range(len(models)):
        # Single line creator
        value, = plt.plot(values[i], styles[i], label=models[i])
        lines.append(value)

    plt.xlabel('Building')
    plt.ylabel(arg + ' value')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
visualize('NMBE')
# Out:
# [array([ -0.22170214,  17.78435903,  -0.78909672, -21.93302262,
#          8.12627715,  -3.41954952,  -2.90041153,  -8.74064714,
#          1.47500449,   6.66953116,  -5.52683418,   4.12367653,
#          2.86574714,  -6.20890326,  -1.0639172 ,  -7.60580998,
#          0.8439433 ,  12.87351757, -10.91172761,  -7.6014097 ,
#         -2.95016987,   0.46891153, -18.01590722, -10.12690623,
#          2.64506246,   2.15417493,  -8.74232848, -12.65904945,
#        -41.32125447, -34.04689936, -37.49381816, -35.36772706,
#        -23.30573357, -41.73027187, -15.15004546,  -9.6309573 ,
#        -63.11122473, -25.12290338, -10.65404653, -36.55469702,
#        -34.02261272, -41.2403052 , -35.09441562, -30.39128721,
#        -37.9012803 , -36.42005085, -28.34866409, -47.93509886,
#        -32.62923748, -35.91819486, -39.23698313, -34.79632104,
#        -13.46039234, -36.30087511, -34.19860279, -17.03431747,
